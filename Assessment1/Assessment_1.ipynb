# %% [markdown]
# Task 1: Cloud/Hosting Solution Review
#
#
#
# When deciding to choose whether to pick a traditional shared web hosting package or a cloud-based platform for a simple Bakery Website, it is important to compare the different services available so you can evaluate the overall costs, scalability, ease of setup/use, maintenance and whether which one will be best for the website. The cost to run this website with a package like Go Daddy will offers a subscription service where for £3.99 a month, this will provide a single website that provides “10GB NVMe storage with a free domain, email, SSL certificate, site security and many optimisation and control tools to fine tune the site. If the website becomes more popular you can opt to increase to the deluxe at £5.99 a month or even the Ultimate Version at £7.49 Per month. This allows you to have an increased storage capacity along with the ability to expand onto more websites with extra functionalities.” (GoDaddy, 2025) GoDaddy enables users to create Websites from premade templates and with the help of AI and Questionnaires the hard bit is sorted for you. The maintenance and updating of the website are all handled by the hosting provider which allows an easier use for the baker.
#
# The other option for a website is to instead use a cloud-based platform such as Azure or AWS. These services offer something different than a dedicated website where they can either pay a subscription fee. Or you can choose to pay as you go instead which offers a higher amount of control. AWS also offers scalability from day one as it is “designed to adapt to fluctuating website traffic, seamlessly accommodating quiet periods and sudden spikes driven by campaigns and social media sharing.” (Amazon, 2025). With these services, it is recommended you have a pre-built website to implement their service onto. In contrast to using web hosting packages, services like AWS are more user oriented where the owner must upkeep and maintain along with update the website which may be a large obstacle to those who may have little to no knowledge of website maintenance.
#
#
#
# In conclusion, I would recommend the 1st option of using a web hosting package to the baker as it would provide the best opportunity and platform to grow their website and business. This is emphasised as the baker has no knowledge regarding websites and what it takes to run and maintain them so a web hosting package that provides all these quality-of-life features are crucial. Another great reason to choose GoDaddy is because of the payment options as, while the AWS services offer a free to use server with limited features, this would negatively impact the scalability of the website and would have to start paying for the extra features on a pay as you go. GoDaddy however has a similar pay as you go function which is fine for the early days of the website but then when the site gets more traffic you can opt to change to a membership which includes the updating, maintaining and expanding of the site.
#
#
#
# Create your website or blog with our WordPress Hosting – GoDaddy UK. (2022). GoDaddy. https://www.godaddy.com/en-uk/hosting/wordpress-hosting
#
# ‌
#
# Web Hosting - Amazon Web Services (AWS). (2025). Amazon Web Services, Inc. https://aws.amazon.com/websites/

# %%
import numpy as np
import matplotlib.pyplot as plt

# # Task 2a

# Define the function
def f(x):
    return np.exp(-x**2 / 3) + 3 * np.sin(x + np.pi / 4)

# Generate x values
x = np.linspace(-2 * np.pi, 2 * np.pi)

# show the y value
y = f(x)

# Plot the function
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='f(x)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('f(x) = exp(-x^2 / 3) + 3 * sin(x + pi / 4)')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# # Task 2b

# Define the function
def x(t):
    return 2 * np.sin(t) * np.exp(np.cos(t))

def y(t):
    return (-3/2) * np.cos(t) * np.exp(np.sin(2*t))

# Generate values of t from 0 to 2π
t_values = np.linspace(0, 2*np.pi, 400)  # 400 points for smooth curve
y_values = y(t_values)  # show y(t) values

# Generate t values
t = np.linspace(0, 2 * np.pi, 400)

# show the x and y value
x = x(t)
y = y(t)

# Plot the function
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Parametric Curve')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('f(x) = 2 * sin(t) * (exp * (cos * t))')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Task 3

random_numbers = np.random.normal(loc = 0, scale = 1, size = 1000)

# Plot the histogram

plt.hist(random_numbers, bins=20, color='green', edgecolor='black', density=True, alpha=0.6, label='Histogram')

# Fit a normal distribution curve
mean = np.mean(random_numbers)
std_dev = np.std(random_numbers)
x = np.linspace(min(random_numbers), max(random_numbers), 1000)
normal_curve = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

# Plot the normal distribution curve
plt.plot(x, normal_curve, color='red', label='Normal Distribution')

# Calculate descriptive statistics
median = np.median(random_numbers)
min_value = np.min(random_numbers)
max_value = np.max(random_numbers)

# Print the statistics
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Standard Deviation: {std_dev}")
print(f"Minimum Value: {min_value}")
print(f"Maximum Value: {max_value}")
# Add labels and title
plt.xlabel('Random Integers')
plt.ylabel('Density')
plt.title('1,000 Random Numbers with Normal Distribution Curve')
plt.legend()
plt.show()
# Out:
# Mean: -0.014811160741740008
# Median: 0.003652470067372656
# Standard Deviation: 0.961054710354731
# Minimum Value: -2.990816385310733
# Maximum Value: 4.05356781265669

# %% [markdown]
# Task 3 Question 5
# a. Is the distribution symmetrical?
# b. How does the mean compare to the median?
# c. Any visible skew?
# d. Differences between an actual normal distribution vs. your sample’s shape?
#
# The histogram above shows a set of integars plotted randomly in a histogram with a distribution curve. the histogram shows a fairly symmetrical center where both sides are mostly mirrored. the peak of the data is shown to be around zero with both sides coming down equally which shows a symmetrical distribution. considering the distribution is close to being perfect this reflects the mean and median which are always going to be very close. due to this distribution there is little to no skew as if skew was present you would be able to see it on one of the sides being stretched than the other, as you can see in the above graph the sides appear similar in length. while the histogram does follow somewhat the distibution curve, small dents and rises still exist. this is to sampling variaties as the normal curve is smoother which is expected in a more finite example.
#
# Task 3 Question 7
# The code itself is designed to create a histogram with 1000 random numbers plotted onto it with a normal distribution curve on top. this allows the generation of calculative descriptive statistics. the functions above creates 1000 random values from a normal distribution of numbers with a mean loc of 0 and a standard deviation of 1. to fit a normal curve onto the graph i have used np.mean and np.std. to overlay the normal curve i wrote pli.plot(x, normal_curve, color ='red') which used a theoretical normal distribution curve to compare my findings with. from this data i am able to extract the Mean, Median, Minimum and maximum values and i finished this off by adding labels, title, and legend in order to make the graph understandable before finally writing plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# Task 4

# Bradley Howson
# 2315432

# 1) Change myID to your own student ID. This MUST be your student ID.
myID = "2315432"  # Change this to your actual student ID

# 2) User input validation
while True:
    try:
        varCount = int(input("Enter an number equal or more than 50: "))
        if varCount >= 50:
            break
        else:
            print("Error: Please enter a number of 50 or more.")
    except ValueError:
        print("Error: wrong input. Please enter a valid number.")

# 3) randSeedNum
s_d = sum(int(d) for d in myID)  # Converts each character in myID to an integer and sums them
random.seed(s_d)

# 4) Random list creation
data = [random.randint(1, 200) for _ in range(varCount)]

# Compute the sum of data
data_sum = sum(data)

# Compute the mean of data
data_mean = data_sum / len(data)

# Compute the minimum and maximum of data
data_min = min(data)
data_max = max(data)

# Print the results
print(f"Sum: {data_sum}, Mean: {data_mean:.2f}, Min: {data_min}, Max: {data_max}")

# Plot a histogram of data
plt.hist(data, bins=10, edgecolor='black', alpha=0.7)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Random Data")
plt.show()
# Out:
# Sum: 5556, Mean: 92.60, Min: 6, Max: 197

# %% [markdown]
# Task 4 - Writeup
#
# The first fix i encountered when browsing the code was the issue surrounding the integer input. i fixed this by placing it into a while loop that would continuously ask the user to place a number above 50 and placed in a try-except method to catch smaller or invalid inputs. the second fix i found was on line 19 where `SSD` was used inside the `random.seed()`. i changed this to be `s-d` instead which now correctly summed the digit of `myID`. from there i completed the given tasks on lines 25-37 which detailed the statistics, sum and results of the data whilst plotting them into a histogram. this code works by telling the user to input a number larger than 50 where is the number entered is less it displays an error message and prompts again. this then uses the student ID and calculates the sum of its digits which is then fed into the random module to make reproducing random numbers. these random numbers are made into a list between 1 and 200. this will then compute and print the sum, mean, minimum and maximum values in the list which plots the data into a histogram using matplotlib which helps to visualise the values.

# %% [markdown]
# Task 5
#
# Over the last two semesters I have worked on new skills whilst building up pre-existing ones. This have been paramount in my developing skill set but it has not come without any issues. During my first semester I ran into a technical problem where I had to upload an image from a sign-up page to a database using python. Unfortunately, no matter how hard I tried I just could not make it work so, to fix this problem I ended up creating a workaround where in the image was saved to the website itself and the path to said image was uploaded to the user's database section. To overcome this challenge, I had to peer through many different YouTube tutorials, how to websites and advice from teachers and friends. Through this advice I managed to create a fix to the issue but was unable to completely fix it. In contrast to this, the part i found easiest in my two semesters was the designing and creating the website itself where I worked with HTML, CSS, and JavaScript. I have found that I am able to use these languages effectively which shows in my work over the past couple of years. I attribute this to my foundation year where I learned my basic HTML skills which I really enjoyed. Due to the issue mentioned above, I have resolved myself to improve my data recognition and python understanding as I am able to create simple and intermediate projects like linking up websites to databases. However, my knowledge and python recognition are not where I would like it to be. To give an example, if I create a python project, I can understand it but if I look at a friend's project, I will take me a while to understand anything going on and I would like to improve my knowledge on how python interacts with each other as well as remembering the different ways to implement it as I find myself having to search up some basic python skills sometimes.
#
#  Over the summer Break I plan to continue my computer science growth by doing some reading on Cyber security sectors, companies, and key valuable information as I have decided to pursue the cyber security pathway. I also plan to start looking into systems that cyber security companies use like pen testing systems.
